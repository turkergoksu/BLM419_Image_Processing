# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
list_1 = [1, '2', 3, 4, 5]

# %%
image_1 = plt.imread('dundar.jpg')

# %%
type(image_1)
# Out:
# numpy.ndarray

# %%
image_1.shape
# 450 row count
# 800 column count
# 3 ise pixeldeki deger muhtemelen 0->R, 1->G, 2->B
# Out:
# (450, 800, 3)

# %%
for row in range(5):
    for col in range(5):
        print(image_1[row, col, 0], image_1[row, col, 1], image_1[row, col, 2])
# Out:
# 232 198 188
# 232 198 188
# 231 199 188
# 231 199 188
# 231 199 188
# 232 198 188
# 232 198 188
# 231 199 188
# 231 199 188
# 231 199 188
# 232 198 188
# 232 198 188
# 231 199 188
# 231 199 188
# 231 199 188
# 232 198 188
# 232 198 188
# 231 199 188
# 231 199 188
# 231 199 188
# 232 198 188
# 232 198 188
# 231 199 188
# 231 199 188
# 231 199 188

# %%
plt.imshow(image_1)
plt.show()
